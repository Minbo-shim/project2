# %%
import numpy as np
import pandas as pd
import requests
import json
import googlemaps

# %%
seoulapt = pd.read_csv("SeoulAPT 도로명.csv", thousands = ',',encoding = 'utf-8')
seoulapt
# Out:
#           거래번호        거래일자     시도   시군구            도로명  \
# 0            1  2018-01-01  서울특별시   강남구        선릉로 120
# 1            2  2018-01-01  서울특별시   강남구      삼성로111길 8
# 2            3  2018-01-01  서울특별시   강남구        역삼로 240
# 3            4  2018-01-01  서울특별시   강서구     등촌로13자길 74
# 4            5  2018-01-01  서울특별시   강서구  등촌로13자길 39-10
# ...        ...         ...    ...   ...            ...
# 291476  291477  2022-12-31  서울특별시   송파구         중대로 24
# 291477  291478  2022-12-31  서울특별시   송파구       올림픽로 435
# 291478  291479  2022-12-31  서울특별시   양천구    목동중앙남로9길 25
# 291479  291480  2022-12-31  서울특별시  영등포구       양평로24길 9
# 291480  291481  2022-12-31  서울특별시   중랑구       용마산로 252
#
#                            주소수식                       주소    건축년도   층  전용면적(㎡)  \
# 0             서울특별시 강남구 선릉로 120        서울특별시 강남구 선릉로 120  1983.0  11  127.610
# 1           서울특별시 강남구 삼성로111길 8      서울특별시 강남구 삼성로111길 8  2008.0  19   84.236
# ...

# %%
gmaps_key = 'AIzaSyBmPcwyuCvWDctc7afFkam67VH77-mNkPg'
gmaps = googlemaps.Client(key = gmaps_key)

# %%
seoulapt['주소']
# Out:
# 0               서울특별시 강남구 선릉로 120
# 1             서울특별시 강남구 삼성로111길 8
# 2               서울특별시 강남구 역삼로 240
# 3            서울특별시 강서구 등촌로13자길 74
# 4         서울특별시 강서구 등촌로13자길 39-10
#                    ...
# 291476           서울특별시 송파구 중대로 24
# 291477         서울특별시 송파구 올림픽로 435
# 291478      서울특별시 양천구 목동중앙남로9길 25
# 291479        서울특별시 영등포구 양평로24길 9
# 291480         서울특별시 중랑구 용마산로 252
# Name: 주소, Length: 291481, dtype: object

# %%
seoulapt_address = [] #주소
seoulapt_lat = [] #위도
seoulapt_lng = [] #경도

for x in seoulapt['주소']:
    tmp = gmaps.geocode(x, language = 'ko')

    seoulapt_address.append(tmp[0].get("formatted_address"))

    tmp_loc= tmp[0].get("geometry")

    seoulapt_lat.append(tmp_loc['location']['lat'])
    seoulapt_lng.append(tmp_loc['location']['lng'])

# %%
seoulapt_lat
# Out:
# [37.491125,
#  37.5138585,
#  37.4973088,
#  37.5374687,
#  37.5375243,
#  37.4941041,
#  37.4751021,
#  37.4916164,
#  37.4785491,
#  37.6676716,
#  37.6734363,
#  37.4910225,
#  37.4875212,
#  37.576394,
#  37.5960337,
#  37.5953754,
#  37.5503253,
#  37.5652954,
#  37.507541,
#  37.52795330000001,
#  37.5346421,
#  37.5310845,
#  37.519073,
#  37.5111805,
#  37.538296,
#  37.5360841,
#  37.6165312,
#  37.5979254,
#  37.6424029,
#  37.5616188,
#  37.5775602,
#  37.5752186,
#  37.5724668,
#  37.5939932,
#  37.4962958,
#  37.4868621,
#  37.5027671,
#  37.4921212,
#  37.4891534,
#  37.4908904,
#  37.4882228,
#  37.4878517,
#  37.4878517,
#  37.512864,
#  37.5155551,
#  37.5159911,
#  37.5161478,
#  37.5170294,
#  37.5274675,
#  37.52622210000001,
#  37.4920842,
#  37.4962673,
#  37.4951647,
#  37.497753,
#  37.482024,
#  37.4741294,
#  37.5274543,
#  37.5317246,
#  37.5479154,
#  37.5532944,
#  37.5532944,
#  37.5461442,
#  37.5317116,
#  37.5535267,
#  37.54127039999999,
# ...

# %%
seoulapt_lng
# Out:
# [127.059896,
#  127.051486,
#  127.042837,
#  126.8537433,
#  126.8556328,
#  126.9281773,
#  126.9324828,
#  126.8616244,
#  126.9014611,
#  127.0622596,
#  127.0480832,
#  126.9768668,
#  126.9068467,
#  126.914527,
#  126.9410451,
#  126.9448171,
#  127.0218814,
#  127.0451834,
#  127.1241693,
#  127.1170212,
#  126.8848163,
#  126.8964041,
#  126.897615,
#  126.9105994,
#  126.955317,
#  126.9691709,
#  126.9266862,
#  126.9071079,
#  126.9310761,
#  127.0227206,
#  127.0806199,
#  127.0795854,
#  127.0870397,
#  127.0750236,
#  127.0766256,
#  127.0645824,
#  127.0561911,
#  127.0432091,
#  127.0487862,
#  127.0421,
#  127.0544393,
#  127.0402271,
#  127.0402271,
#  127.0440149,
#  127.0423675,
#  127.0462275,
#  127.0622076,
#  127.0427453,
#  127.0372259,
#  127.0244795,
#  127.0348905,
#  127.0463755,
#  127.0472447,
#  127.0467808,
#  127.0821324,
#  127.0940867,
#  127.0522366,
#  127.1465338,
#  127.1508631,
#  127.1484591,
#  127.1484591,
#  127.1674872,
#  127.1245317,
# ...

# %%
seoulapt['위도'] = seoulapt_lat

# %%
seoulapt['경도'] = seoulapt_lng

# %%
seoulapt
# Out:
#           거래번호        거래일자     시도   시군구            도로명  \
# 0            1  2018-01-01  서울특별시   강남구        선릉로 120
# 1            2  2018-01-01  서울특별시   강남구      삼성로111길 8
# 2            3  2018-01-01  서울특별시   강남구        역삼로 240
# 3            4  2018-01-01  서울특별시   강서구     등촌로13자길 74
# 4            5  2018-01-01  서울특별시   강서구  등촌로13자길 39-10
# ...        ...         ...    ...   ...            ...
# 291476  291477  2022-12-31  서울특별시   송파구         중대로 24
# 291477  291478  2022-12-31  서울특별시   송파구       올림픽로 435
# 291478  291479  2022-12-31  서울특별시   양천구    목동중앙남로9길 25
# 291479  291480  2022-12-31  서울특별시  영등포구       양평로24길 9
# 291480  291481  2022-12-31  서울특별시   중랑구       용마산로 252
#
#                            주소수식                       주소    건축년도   층  전용면적(㎡)  \
# 0             서울특별시 강남구 선릉로 120        서울특별시 강남구 선릉로 120  1983.0  11  127.610
# 1           서울특별시 강남구 삼성로111길 8      서울특별시 강남구 삼성로111길 8  2008.0  19   84.236
# ...

# %%
seoulapt.to_csv('C:/Users/USER/Desktop/seoulapt_loc.csv', index=False)
